# %%
import pandas as pd

# %%
df = pd.read_csv("/content/cosmetics.csv")

df
# Out:
#             Label                          Brand  \
# 0     Moisturizer                         LA MER
# 1     Moisturizer                          SK-II
# 2     Moisturizer                 DRUNK ELEPHANT
# 3     Moisturizer                         LA MER
# 4     Moisturizer                   IT COSMETICS
# ...           ...                            ...
# 1467  Sun protect                         KORRES
# 1468  Sun protect                KATE SOMERVILLE
# 1469  Sun protect                  VITA LIBERATA
# 1470  Sun protect  ST. TROPEZ TANNING ESSENTIALS
# 1471  Sun protect                     DERMAFLASH
#
#                                                    Name  Price  Rank  \
# 0                                       Crème de la Mer    175   4.1
# 1                              Facial Treatment Essence    179   4.1
# 2                            Protini™ Polypeptide Cream     68   4.4
# 3                           The Moisturizing Soft Cream    175   3.8
# 4         Your Skin But Better™ CC+™ Cream with SPF 50+     38   4.1
# ...                                                 ...    ...   ...
# 1467  Yoghurt Nourishing Fluid Veil Face Sunscreen B...     35   3.9
# 1468  Daily Deflector™ Waterlight Broad Spectrum SPF...     48   3.6
# 1469                            Self Tan Dry Oil SPF 50     54   3.5
# 1470                   Pro Light Self Tan Bronzing Mist     20   1.0
# 1471  DERMAPROTECT Daily Defense Broad Spectrum SPF 50+     45   0.0
#
#                                             Ingredients  Combination  Dry  \
# 0     Algae (Seaweed) Extract, Mineral Oil, Petrolat...            1    1
# 1     Galactomyces Ferment Filtrate (Pitera), Butyle...            1    1
# 2     Water, Dicaprylyl Carbonate, Glycerin, Ceteary...            1    1
# 3     Algae (Seaweed) Extract, Cyclopentasiloxane, P...            1    1
# 4     Water, Snail Secretion Filtrate, Phenyl Trimet...            1    1
# ...                                                 ...          ...  ...
# 1467  Water, Alcohol Denat., Potassium Cetyl Phospha...            1    1
# 1468  Water, Isododecane, Dimethicone, Butyloctyl Sa...            0    0
# 1469  Water, Dihydroxyacetone, Glycerin, Sclerocarya...            0    0
# 1470  Water, Dihydroxyacetone, Propylene Glycol, PPG...            0    0
# 1471                      Visit the DERMAFLASH boutique            1    1
#
#       Normal  Oily  Sensitive
# 0          1     1          1
# 1          1     1          1
# 2          1     1          0
# 3          1     1          1
# 4          1     1          1
# ...      ...   ...        ...
# 1467       1     1          1
# 1468       0     0          0
# 1469       0     0          0
# 1470       0     0          0
# 1471       1     1          1
#
# [1472 rows x 11 columns]

# %% [markdown]
# **Data Understanding**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1472 entries, 0 to 1471
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Label        1472 non-null   object
#  1   Brand        1472 non-null   object
#  2   Name         1472 non-null   object
#  3   Price        1472 non-null   int64
#  4   Rank         1472 non-null   float64
#  5   Ingredients  1472 non-null   object
#  6   Combination  1472 non-null   int64
#  7   Dry          1472 non-null   int64
#  8   Normal       1472 non-null   int64
#  9   Oily         1472 non-null   int64
#  10  Sensitive    1472 non-null   int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 126.6+ KB

# %%
df.shape
# Out:
# (1472, 11)

# %%
df.dtypes
# Out:
# Label           object
# Brand           object
# Name            object
# Price            int64
# Rank           float64
# Ingredients     object
# Combination      int64
# Dry              int64
# Normal           int64
# Oily             int64
# Sensitive        int64
# dtype: object

# %%
df.describe()
# Out:
#              Price         Rank  Combination          Dry       Normal  \
# count  1472.000000  1472.000000   1472.00000  1472.000000  1472.000000
# mean     55.584239     4.153261      0.65625     0.614130     0.652174
# std      45.014429     0.633918      0.47512     0.486965     0.476442
# min       3.000000     0.000000      0.00000     0.000000     0.000000
# 25%      30.000000     4.000000      0.00000     0.000000     0.000000
# 50%      42.500000     4.300000      1.00000     1.000000     1.000000
# 75%      68.000000     4.500000      1.00000     1.000000     1.000000
# max     370.000000     5.000000      1.00000     1.000000     1.000000
#
#               Oily    Sensitive
# count  1472.000000  1472.000000
# mean      0.607337     0.513587
# std       0.488509     0.499985
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       1.000000     1.000000
# 75%       1.000000     1.000000
# max       1.000000     1.000000

# %% [markdown]
# **Data Preparation**

# %% [markdown]
# Missing Values

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Label          0.0
# Brand          0.0
# Name           0.0
# Price          0.0
# Rank           0.0
# Ingredients    0.0
# Combination    0.0
# Dry            0.0
# Normal         0.0
# Oily           0.0
# Sensitive      0.0
# dtype: float64

# %% [markdown]
# Duplicated Values

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Label, Brand, Name, Price, Rank, Ingredients, Combination, Dry, Normal, Oily, Sensitive]
# Index: []

# %% [markdown]
# Outliers

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - (1.5 * iqr)
  upper_bound = q3 + (1.5 * iqr)
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers) / len(df)) * 100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

  # Dataframe dari list hasil
  results_df = pd.DataFrame(results)
  results_df.set_index('Kolom', inplace=True)
  results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

  # Tampilkan dataframe
  display(results_df)
# Out:
# Kolom  Persentase Outliers
# Price             6.182065
# Kolom  Persentase Outliers
# Price             6.182065
# Rank              3.396739
# Kolom        Persentase Outliers
# Price                   6.182065
# Rank                    3.396739
# Combination             0.000000
# Kolom        Persentase Outliers
# Price                   6.182065
# Rank                    3.396739
# Combination             0.000000
# Dry                     0.000000
# Kolom        Persentase Outliers
# Price                   6.182065
# Rank                    3.396739
# Combination             0.000000
# Dry                     0.000000
# Normal                  0.000000
# Kolom        Persentase Outliers
# Price                   6.182065
# Rank                    3.396739
# Combination             0.000000
# Dry                     0.000000
# Normal                  0.000000
# Oily                    0.000000
# Kolom        Persentase Outliers
# Price                   6.182065
# Rank                    3.396739
# Combination             0.000000
# Dry                     0.000000
# Normal                  0.000000
# Oily                    0.000000
# Sensitive               0.000000

# %%
columns_to_impute = ["Price", "Rank"]

for col in columns_to_impute:
  Q1 = df[col].quantile(0.25)
  Q3 = df[col].quantile(0.75)
  IQR = Q3 - Q1
  lower_bound = Q1 - (1.5 * IQR)
  upper_bound = Q3 + (1.5 * IQR)

  # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
  df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - (1.5 * iqr)
  upper_bound = q3 + (1.5 * iqr)
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers) / len(df)) * 100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

  # Dataframe dari list hasil
  results_df = pd.DataFrame(results)
  results_df.set_index('Kolom', inplace=True)
  results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

  # Tampilkan dataframe
  display(results_df)
# Out:
# Kolom  Persentase Outliers
# Price                  0.0
# Kolom  Persentase Outliers
# Price                  0.0
# Rank                   0.0
# Kolom        Persentase Outliers
# Price                        0.0
# Rank                         0.0
# Combination                  0.0
# Kolom        Persentase Outliers
# Price                        0.0
# Rank                         0.0
# Combination                  0.0
# Dry                          0.0
# Kolom        Persentase Outliers
# Price                        0.0
# Rank                         0.0
# Combination                  0.0
# Dry                          0.0
# Normal                       0.0
# Kolom        Persentase Outliers
# Price                        0.0
# Rank                         0.0
# Combination                  0.0
# Dry                          0.0
# Normal                       0.0
# Oily                         0.0
# Kolom        Persentase Outliers
# Price                        0.0
# Rank                         0.0
# Combination                  0.0
# Dry                          0.0
# Normal                       0.0
# Oily                         0.0
# Sensitive                    0.0

# %% [markdown]
# Construct Data

# %%
df['PriceCategory'] = pd.cut(df['Price'], bins=[0, 50, 100, float('inf')], labels=['Low', 'Medium', 'High'])
df
# Out:
#             Label                          Brand  \
# 0     Moisturizer                         LA MER
# 1     Moisturizer                          SK-II
# 2     Moisturizer                 DRUNK ELEPHANT
# 3     Moisturizer                         LA MER
# 4     Moisturizer                   IT COSMETICS
# ...           ...                            ...
# 1467  Sun protect                         KORRES
# 1468  Sun protect                KATE SOMERVILLE
# 1469  Sun protect                  VITA LIBERATA
# 1470  Sun protect  ST. TROPEZ TANNING ESSENTIALS
# 1471  Sun protect                     DERMAFLASH
#
#                                                    Name  Price  Rank  \
# 0                                       Crème de la Mer    125  4.10
# 1                              Facial Treatment Essence    125  4.10
# 2                            Protini™ Polypeptide Cream     68  4.40
# 3                           The Moisturizing Soft Cream    125  3.80
# 4         Your Skin But Better™ CC+™ Cream with SPF 50+     38  4.10
# ...                                                 ...    ...   ...
# 1467  Yoghurt Nourishing Fluid Veil Face Sunscreen B...     35  3.90
# 1468  Daily Deflector™ Waterlight Broad Spectrum SPF...     48  3.60
# 1469                            Self Tan Dry Oil SPF 50     54  3.50
# 1470                   Pro Light Self Tan Bronzing Mist     20  3.25
# 1471  DERMAPROTECT Daily Defense Broad Spectrum SPF 50+     45  3.25
#
#                                             Ingredients  Combination  Dry  \
# 0     Algae (Seaweed) Extract, Mineral Oil, Petrolat...            1    1
# 1     Galactomyces Ferment Filtrate (Pitera), Butyle...            1    1
# 2     Water, Dicaprylyl Carbonate, Glycerin, Ceteary...            1    1
# 3     Algae (Seaweed) Extract, Cyclopentasiloxane, P...            1    1
# 4     Water, Snail Secretion Filtrate, Phenyl Trimet...            1    1
# ...                                                 ...          ...  ...
# 1467  Water, Alcohol Denat., Potassium Cetyl Phospha...            1    1
# 1468  Water, Isododecane, Dimethicone, Butyloctyl Sa...            0    0
# 1469  Water, Dihydroxyacetone, Glycerin, Sclerocarya...            0    0
# 1470  Water, Dihydroxyacetone, Propylene Glycol, PPG...            0    0
# 1471                      Visit the DERMAFLASH boutique            1    1
#
#       Normal  Oily  Sensitive PriceCategory
# 0          1     1          1          High
# 1          1     1          1          High
# 2          1     1          0        Medium
# 3          1     1          1          High
# 4          1     1          1           Low
# ...      ...   ...        ...           ...
# 1467       1     1          1           Low
# 1468       0     0          0           Low
# 1469       0     0          0        Medium
# 1470       0     0          0           Low
# 1471       1     1          1           Low
#
# [1472 rows x 12 columns]

# %% [markdown]
# Data Reduction

# %%
df = df.drop(columns=['Price'])
df
# Out:
#             Label                          Brand  \
# 0     Moisturizer                         LA MER
# 1     Moisturizer                          SK-II
# 2     Moisturizer                 DRUNK ELEPHANT
# 3     Moisturizer                         LA MER
# 4     Moisturizer                   IT COSMETICS
# ...           ...                            ...
# 1467  Sun protect                         KORRES
# 1468  Sun protect                KATE SOMERVILLE
# 1469  Sun protect                  VITA LIBERATA
# 1470  Sun protect  ST. TROPEZ TANNING ESSENTIALS
# 1471  Sun protect                     DERMAFLASH
#
#                                                    Name  Rank  \
# 0                                       Crème de la Mer  4.10
# 1                              Facial Treatment Essence  4.10
# 2                            Protini™ Polypeptide Cream  4.40
# 3                           The Moisturizing Soft Cream  3.80
# 4         Your Skin But Better™ CC+™ Cream with SPF 50+  4.10
# ...                                                 ...   ...
# 1467  Yoghurt Nourishing Fluid Veil Face Sunscreen B...  3.90
# 1468  Daily Deflector™ Waterlight Broad Spectrum SPF...  3.60
# 1469                            Self Tan Dry Oil SPF 50  3.50
# 1470                   Pro Light Self Tan Bronzing Mist  3.25
# 1471  DERMAPROTECT Daily Defense Broad Spectrum SPF 50+  3.25
#
#                                             Ingredients  Combination  Dry  \
# 0     Algae (Seaweed) Extract, Mineral Oil, Petrolat...            1    1
# 1     Galactomyces Ferment Filtrate (Pitera), Butyle...            1    1
# 2     Water, Dicaprylyl Carbonate, Glycerin, Ceteary...            1    1
# 3     Algae (Seaweed) Extract, Cyclopentasiloxane, P...            1    1
# 4     Water, Snail Secretion Filtrate, Phenyl Trimet...            1    1
# ...                                                 ...          ...  ...
# 1467  Water, Alcohol Denat., Potassium Cetyl Phospha...            1    1
# 1468  Water, Isododecane, Dimethicone, Butyloctyl Sa...            0    0
# 1469  Water, Dihydroxyacetone, Glycerin, Sclerocarya...            0    0
# 1470  Water, Dihydroxyacetone, Propylene Glycol, PPG...            0    0
# 1471                      Visit the DERMAFLASH boutique            1    1
#
#       Normal  Oily  Sensitive PriceCategory
# 0          1     1          1          High
# 1          1     1          1          High
# 2          1     1          0        Medium
# 3          1     1          1          High
# 4          1     1          1           Low
# ...      ...   ...        ...           ...
# 1467       1     1          1           Low
# 1468       0     0          0           Low
# 1469       0     0          0        Medium
# 1470       0     0          0           Low
# 1471       1     1          1           Low
#
# [1472 rows x 11 columns]
